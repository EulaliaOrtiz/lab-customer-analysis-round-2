# %%
# Lab | Customer Analysis Round 2

#For this lab, we will be using the `marketing_customer_analysis.csv` file that you can find in the `files_for_lab` folder. 
#Check out the `files_for_lab/about.md` to get more information if you are using the Online Excel.

#**Note**: For the next labs we will be using the same data file. 
#Please save the code, so that you can re-use it later in the labs following this lab.
### Dealing with the data

# %%
import pandas as pd
import numpy as np

# %%
file = pd.read_csv('marketing_customer_analysis.csv')

# %%
#1. Show the dataframe shape.

# %%
display(file.head())
display(file.tail())
file.shape
# Out:
#    Unnamed: 0 Customer       State  Customer Lifetime Value Response  \
# 0           0  DK49336     Arizona              4809.216960       No
# 1           1  KX64629  California              2228.525238       No
# 2           2  LZ68649  Washington             14947.917300       No
# 3           3  XL78013      Oregon             22332.439460      Yes
# 4           4  QA50777      Oregon              9025.067525       No
#
#    Coverage Education Effective To Date EmploymentStatus Gender  ...  \
# 0     Basic   College           2/18/11         Employed      M  ...
# 1     Basic   College           1/18/11       Unemployed      F  ...
# 2     Basic  Bachelor           2/10/11         Employed      M  ...
# 3  Extended   College           1/11/11         Employed      M  ...
# 4   Premium  Bachelor           1/17/11    Medical Leave      F  ...
#
#    Number of Open Complaints Number of Policies     Policy Type        Policy  \
# ...

# %%
file.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10910 entries, 0 to 10909
# Data columns (total 26 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Unnamed: 0                     10910 non-null  int64
#  1   Customer                       10910 non-null  object
#  2   State                          10279 non-null  object
#  3   Customer Lifetime Value        10910 non-null  float64
#  4   Response                       10279 non-null  object
#  5   Coverage                       10910 non-null  object
#  6   Education                      10910 non-null  object
#  7   Effective To Date              10910 non-null  object
#  8   EmploymentStatus               10910 non-null  object
#  9   Gender                         10910 non-null  object
#  10  Income                         10910 non-null  int64
#  11  Location Code                  10910 non-null  object
# ...

# %%
file.describe()
# Out:
#          Unnamed: 0  Customer Lifetime Value        Income  \
# count  10910.000000             10910.000000  10910.000000
# mean    5454.500000              8018.241094  37536.284785
# std     3149.590053              6885.081434  30359.195670
# min        0.000000              1898.007675      0.000000
# 25%     2727.250000              4014.453113      0.000000
# 50%     5454.500000              5771.147235  33813.500000
# 75%     8181.750000              8992.779137  62250.750000
# max    10909.000000             83325.381190  99981.000000
#
#        Monthly Premium Auto  Months Since Last Claim  \
# count          10910.000000             10277.000000
# mean              93.196059                15.149071
# std               34.442532                10.080349
# min               61.000000                 0.000000
# 25%               68.000000                 6.000000
# 50%               83.000000                14.000000
# 75%              109.000000                23.000000
# ...

# %%
#2. Standardize header names.

# %%
file.columns
# Out:
# Index(['Unnamed: 0', 'Customer', 'State', 'Customer Lifetime Value',
#        'Response', 'Coverage', 'Education', 'Effective To Date',
#        'EmploymentStatus', 'Gender', 'Income', 'Location Code',
#        'Marital Status', 'Monthly Premium Auto', 'Months Since Last Claim',
#        'Months Since Policy Inception', 'Number of Open Complaints',
#        'Number of Policies', 'Policy Type', 'Policy', 'Renew Offer Type',
#        'Sales Channel', 'Total Claim Amount', 'Vehicle Class', 'Vehicle Size',
#        'Vehicle Type'],
#       dtype='object')

# %%
cols = []
for col in file.columns: 
    column = col.lower()
    column = column.replace(" ", "_")
    cols.append(column)
cols
# Out:
# ['unnamed:_0',
#  'customer',
#  'state',
#  'customer_lifetime_value',
#  'response',
#  'coverage',
#  'education',
#  'effective_to_date',
#  'employmentstatus',
#  'gender',
#  'income',
#  'location_code',
#  'marital_status',
#  'monthly_premium_auto',
#  'months_since_last_claim',
#  'months_since_policy_inception',
#  'number_of_open_complaints',
#  'number_of_policies',
#  'policy_type',
#  'policy',
#  'renew_offer_type',
#  'sales_channel',
#  'total_claim_amount',
#  'vehicle_class',
#  'vehicle_size',
#  'vehicle_type']

# %%
file.columns = cols
file.head()
# Out:
#    unnamed:_0 customer       state  customer_lifetime_value response  \
# 0           0  DK49336     Arizona              4809.216960       No
# 1           1  KX64629  California              2228.525238       No
# 2           2  LZ68649  Washington             14947.917300       No
# 3           3  XL78013      Oregon             22332.439460      Yes
# 4           4  QA50777      Oregon              9025.067525       No
#
#    coverage education effective_to_date employmentstatus gender  ...  \
# 0     Basic   College           2/18/11         Employed      M  ...
# 1     Basic   College           1/18/11       Unemployed      F  ...
# 2     Basic  Bachelor           2/10/11         Employed      M  ...
# 3  Extended   College           1/11/11         Employed      M  ...
# 4   Premium  Bachelor           1/17/11    Medical Leave      F  ...
#
#    number_of_open_complaints number_of_policies     policy_type        policy  \
# ...

# %%
#3. Which columns are numerical?
#4. Which columns are categorical?

# %%
file.dtypes
# Out:
# unnamed:_0                         int64
# customer                          object
# state                             object
# customer_lifetime_value          float64
# response                          object
# coverage                          object
# education                         object
# effective_to_date                 object
# employmentstatus                  object
# gender                            object
# income                             int64
# location_code                     object
# marital_status                    object
# monthly_premium_auto               int64
# months_since_last_claim          float64
# months_since_policy_inception      int64
# number_of_open_complaints        float64
# number_of_policies                 int64
# policy_type                       object
# policy                            object
# renew_offer_type                  object
# sales_channel                     object
# total_claim_amount               float64
# ...

# %%
numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
file.select_dtypes(include=numerics).columns
# Out:
# Index(['unnamed:_0', 'customer_lifetime_value', 'income',
#        'monthly_premium_auto', 'months_since_last_claim',
#        'months_since_policy_inception', 'number_of_open_complaints',
#        'number_of_policies', 'total_claim_amount'],
#       dtype='object')

# %%
file.select_dtypes(include='object').columns
# Out:
# Index(['customer', 'state', 'response', 'coverage', 'education',
#        'effective_to_date', 'employmentstatus', 'gender', 'location_code',
#        'marital_status', 'policy_type', 'policy', 'renew_offer_type',
#        'sales_channel', 'vehicle_class', 'vehicle_size', 'vehicle_type'],
#       dtype='object')

# %%
file['state'].unique()
# Out:
# array(['Arizona', 'California', 'Washington', 'Oregon', nan, 'Nevada'],
#       dtype=object)

# %%
file['response'].unique()
# Out:
# array(['No', 'Yes', nan], dtype=object)

# %%
file['coverage'].unique()
# Out:
# array(['Basic', 'Extended', 'Premium'], dtype=object)

# %%
file['education'].unique()
# Out:
# array(['College', 'Bachelor', 'High School or Below', 'Doctor', 'Master'],
#       dtype=object)

# %%
file['effective_to_date'].unique()
# Out:
# array(['2/18/11', '1/18/11', '2/10/11', '1/11/11', '1/17/11', '2/14/11',
#        '2/24/11', '1/19/11', '1/4/11', '1/2/11', '2/7/11', '1/31/11',
#        '1/26/11', '2/28/11', '1/16/11', '2/26/11', '2/23/11', '1/15/11',
#        '2/2/11', '2/15/11', '1/24/11', '2/21/11', '2/22/11', '1/7/11',
#        '1/28/11', '2/8/11', '2/12/11', '2/20/11', '1/5/11', '2/19/11',
#        '1/3/11', '2/3/11', '1/22/11', '1/23/11', '2/5/11', '2/13/11',
#        '1/25/11', '2/16/11', '2/1/11', '1/27/11', '1/12/11', '1/20/11',
#        '2/6/11', '2/11/11', '1/21/11', '1/29/11', '1/9/11', '2/9/11',
#        '2/27/11', '1/1/11', '2/17/11', '2/25/11', '1/13/11', '1/6/11',
#        '2/4/11', '1/14/11', '1/10/11', '1/8/11', '1/30/11'], dtype=object)

# %%
file['employmentstatus'].unique()
# Out:
# array(['Employed', 'Unemployed', 'Medical Leave', 'Disabled', 'Retired'],
#       dtype=object)

# %%
file['gender'].unique()
# Out:
# array(['M', 'F'], dtype=object)

# %%
file['location_code'].unique()
# Out:
# array(['Suburban', 'Urban', 'Rural'], dtype=object)

# %%
file['marital_status'].unique()
# Out:
# array(['Married', 'Single', 'Divorced'], dtype=object)

# %%
file['policy_type'].unique()
# Out:
# array(['Corporate Auto', 'Personal Auto', 'Special Auto'], dtype=object)

# %%
file['policy'].unique()
# Out:
# array(['Corporate L3', 'Personal L3', 'Personal L2', 'Corporate L2',
#        'Personal L1', 'Special L1', 'Corporate L1', 'Special L3',
#        'Special L2'], dtype=object)

# %%
file['renew_offer_type'].unique()
# Out:
# array(['Offer3', 'Offer4', 'Offer2', 'Offer1'], dtype=object)

# %%
file['sales_channel'].unique()
# Out:
# array(['Agent', 'Call Center', 'Branch', 'Web'], dtype=object)

# %%
file['vehicle_class'].unique()
# Out:
# array(['Four-Door Car', 'SUV', 'Two-Door Car', 'Sports Car', 'Luxury Car',
#        'Luxury SUV', nan], dtype=object)

# %%
file['vehicle_size'].unique()
# Out:
# array(['Medsize', 'Small', 'Large', nan], dtype=object)

# %%
file['vehicle_type'].unique()
# Out:
# array([nan, 'A'], dtype=object)

# %%
#5. Check and deal with `NaN` values

# %%
file.isna().sum()
# Out:
# unnamed:_0                          0
# customer                            0
# state                             631
# customer_lifetime_value             0
# response                          631
# coverage                            0
# education                           0
# effective_to_date                   0
# employmentstatus                    0
# gender                              0
# income                              0
# location_code                       0
# marital_status                      0
# monthly_premium_auto                0
# months_since_last_claim           633
# months_since_policy_inception       0
# number_of_open_complaints         633
# number_of_policies                  0
# policy_type                         0
# policy                              0
# renew_offer_type                    0
# sales_channel                       0
# total_claim_amount                  0
# vehicle_class                     622
# vehicle_size                      622
# ...

# %%
#Dropping columns with missing values -categorical-. Vehicle type has too many missing values. Unnamed is useless. 
#Dropping also state -concentrated in the east coast- knowing that it will not be used for the rest of the exercises (but aware that we have that info and it could be possible to use it for other purposes)
#Dropping vehicle class and vehicle size, could be used in the future replacing missing values by the mode, if necessary.
#Dropping number of open complaints (somehow redundant as we have the total claim amount)
#Dropping months since last claim, for the sake of time. 

filedr = file.drop(columns=['vehicle_type', 'unnamed:_0','state','vehicle_class','vehicle_size','months_since_last_claim', 'number_of_open_complaints'])
filedr.head()
# Out:
#   customer  customer_lifetime_value response  coverage education  \
# 0  DK49336              4809.216960       No     Basic   College
# 1  KX64629              2228.525238       No     Basic   College
# 2  LZ68649             14947.917300       No     Basic  Bachelor
# 3  XL78013             22332.439460      Yes  Extended   College
# 4  QA50777              9025.067525       No   Premium  Bachelor
#
#   effective_to_date employmentstatus gender  income location_code  \
# 0           2/18/11         Employed      M   48029      Suburban
# 1           1/18/11       Unemployed      F       0      Suburban
# 2           2/10/11         Employed      M   22139      Suburban
# 3           1/11/11         Employed      M   49078      Suburban
# 4           1/17/11    Medical Leave      F   23675      Suburban
#
#   marital_status  monthly_premium_auto  months_since_policy_inception  \
# 0        Married                    61                             52
# ...

# %%
sum(filedr.isna().sum(1)>=1)
# Out:
# 631

# %%
#Dealing with the missing values in response.
#My idea would be to replace the Nan using this proportion 1466/8813 randomly with a function. 
#It would take me a lot of time to design this function with my current knowledge, so I am dropping the column.

# %%
fresponse=file.loc[0:,['response']]
fresponse.head()
# Out:
#   response
# 0       No
# 1       No
# 2       No
# 3      Yes
# 4       No

# %%
filedr['response'].value_counts()
# Out:
# No     8813
# Yes    1466
# Name: response, dtype: int64

# %%
1466/8813 #My idea would be to replace the Nan in this proportion randomly with a function. 
#It would take me a lot of time to design this function with my current knowledge, so I dropped the column.
# Out:
# 0.16634517190514014

# %%
filedr = file.drop(columns=['response'])
filedr.head()
# Out:
#    unnamed:_0 customer       state  customer_lifetime_value  coverage  \
# 0           0  DK49336     Arizona              4809.216960     Basic
# 1           1  KX64629  California              2228.525238     Basic
# 2           2  LZ68649  Washington             14947.917300     Basic
# 3           3  XL78013      Oregon             22332.439460  Extended
# 4           4  QA50777      Oregon              9025.067525   Premium
#
#   education effective_to_date employmentstatus gender  income  ...  \
# 0   College           2/18/11         Employed      M   48029  ...
# 1   College           1/18/11       Unemployed      F       0  ...
# 2  Bachelor           2/10/11         Employed      M   22139  ...
# 3   College           1/11/11         Employed      M   49078  ...
# 4  Bachelor           1/17/11    Medical Leave      F   23675  ...
#
#   number_of_open_complaints number_of_policies     policy_type        policy  \
# ...

# %%
#6. Datetime format - 
#Extract the months from the dataset and store in a separate column. 
#Then filter the data to show only the information for the first quarter , ie. January, February and March. _
#Hint_: If data from March does not exist, consider only January and February.
file['date_time'][0].day
file['date_time'][0].month
file['date_time'][0].year
file['date_time'][0].isoweekday()  # Returns 1 for Monday and so on

file['date_time'][0].time()
file['date_time'][0].isoweekday()
file['date_time'][0].isoformat()
file['date_time'][0].strftime(format='%d-%m-%Y')
file['date_time'][0].strftime(format="%A %d. %B %Y")

# %%
copy= filedr.copy()
copy.head()
# Out:
#   customer  customer_lifetime_value  coverage education effective_to_date  \
# 0  DK49336              4809.216960     Basic   College           2/18/11
# 1  KX64629              2228.525238     Basic   College           1/18/11
# 2  LZ68649             14947.917300     Basic  Bachelor           2/10/11
# 3  XL78013             22332.439460  Extended   College           1/11/11
# 4  QA50777              9025.067525   Premium  Bachelor           1/17/11
#
#   employmentstatus gender  income location_code marital_status  \
# 0         Employed      M   48029      Suburban        Married
# 1       Unemployed      F       0      Suburban         Single
# 2         Employed      M   22139      Suburban         Single
# 3         Employed      M   49078      Suburban         Single
# 4    Medical Leave      F   23675      Suburban        Married
#
#    monthly_premium_auto  months_since_policy_inception  number_of_policies  \
# ...

# %%
copy['date_time'][4].month
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'date_time'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
#7. BONUS: Put all the previously mentioned data transformations into a function

# %%
#Lab customer analysis 3
#For this lab, we still keep using the marketing_customer_analysis.csv file. 
#You can find the file in the files_for_lab folder.
#Use the same jupyter file from the last lab, Customer Analysis Round 3

# %%
filel3 = pd.read_csv('marketing_customer_analysislab3.csv')

# %%
#EDA (Exploratory Data Analysis) - Complete the following tasks to explore the data:
#Show DataFrame info.
#Describe DataFrame.

# %%
display(filel3.head())
filel3.shape
# Out:
#   Customer       State  Customer Lifetime Value Response  Coverage Education  \
# 0  BU79786  Washington              2763.519279       No     Basic  Bachelor
# 1  QZ44356     Arizona              6979.535903       No  Extended  Bachelor
# 2  AI49188      Nevada             12887.431650       No   Premium  Bachelor
# 3  WW63253  California              7645.861827       No     Basic  Bachelor
# 4  HB64268  Washington              2813.692575       No     Basic  Bachelor
#
#   Effective To Date EmploymentStatus Gender  Income  ...  \
# 0           2/24/11         Employed      F   56274  ...
# 1           1/31/11       Unemployed      F       0  ...
# 2           2/19/11         Employed      F   48767  ...
# 3           1/20/11       Unemployed      M       0  ...
# 4            2/3/11         Employed      M   43836  ...
#
#   Months Since Policy Inception Number of Open Complaints  Number of Policies  \
# ...

# %%
filel3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9134 entries, 0 to 9133
# Data columns (total 24 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Customer                       9134 non-null   object
#  1   State                          9134 non-null   object
#  2   Customer Lifetime Value        9134 non-null   float64
#  3   Response                       9134 non-null   object
#  4   Coverage                       9134 non-null   object
#  5   Education                      9134 non-null   object
#  6   Effective To Date              9134 non-null   object
#  7   EmploymentStatus               9134 non-null   object
#  8   Gender                         9134 non-null   object
#  9   Income                         9134 non-null   int64
#  10  Location Code                  9134 non-null   object
#  11  Marital Status                 9134 non-null   object
# ...

# %%
filel3.describe().T
# Out:
#                                 count          mean           std  \
# Customer Lifetime Value        9134.0   8004.940475   6870.967608
# Income                         9134.0  37657.380009  30379.904734
# Monthly Premium Auto           9134.0     93.219291     34.407967
# Months Since Last Claim        9134.0     15.097000     10.073257
# Months Since Policy Inception  9134.0     48.064594     27.905991
# Number of Open Complaints      9134.0      0.384388      0.910384
# Number of Policies             9134.0      2.966170      2.390182
# Total Claim Amount             9134.0    434.088794    290.500092
#
#                                        min          25%           50%  \
# Customer Lifetime Value        1898.007675  3994.251794   5780.182197
# Income                            0.000000     0.000000  33889.500000
# Monthly Premium Auto             61.000000    68.000000     83.000000
# Months Since Last Claim           0.000000     6.000000     14.000000
# ...

# %%
filel3.describe(include=[np.object]).T #ojo, yo creía que con esto encontraba la descripción de los object. 
#No sé qué me está diciendo python.
# Out:
# C:\Users\31612\AppData\Local\Temp/ipykernel_13668/4283784735.py:1: DeprecationWarning: `np.object` is a deprecated alias for the builtin `object`. To silence this warning, use `object` by itself. Doing this will not modify any behavior and is safe.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   filel3.describe(include=[np.object]).T #ojo, yo creía que con esto encontraba la descripción de los object.
#                   count unique            top  freq
# Customer           9134   9134        BU79786     1
# State              9134      5     California  3150
# Response           9134      2             No  7826
# Coverage           9134      3          Basic  5568
# Education          9134      5       Bachelor  2748
# Effective To Date  9134     59        1/10/11   195
# EmploymentStatus   9134      5       Employed  5698
# Gender             9134      2              F  4658
# ...

# %%
#Show a plot of the total number of responses.

# %%
import matplotlib.pyplot as plt
import seaborn as sns 
# %matplotlib inline

# %%
#sns.barplot(x=, y='Response', filel3=filel3)  #estos códigos me dan error
#plt.show()
# Out:
#   File "C:\Users\31612\AppData\Local\Temp/ipykernel_26188/1012582482.py", line 1
#     sns.barplot(x=, y='Response', filel3=filel3)
#                   ^
# SyntaxError: invalid syntax

# %%
sns.displot(filel3['Response'])
plt.show()

# %%
#Show a plot of the response rate by the sales channel.

# %%
sns.displot(data=filel3, x="Sales Channel", hue="Response", multiple="stack")
plt.show()

# %%
#Show a plot of the response rate by the total claim amount.

# %%
sns.displot(data=filel3, x="Response", hue="Total Claim Amount", multiple="stack")
sns.set(rc={"figure.figsize":(2, 2)}) #TRYING TO REDUCE THE SIZE OF THE CHART SO IT SHOWS IT TO ME
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# ~\anaconda3\lib\site-packages\IPython\core\pylabtools.py in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     149         FigureCanvasBase(fig)
#     150
# --> 151     fig.canvas.print_figure(bytes_io, **kw)
#     152     data = bytes_io.getvalue()
#     153     if fmt == 'svg':
#
# ~\anaconda3\lib\site-packages\matplotlib\backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
# ...

# %%
#Show a plot of the response rate by income.

# %%
sns.displot(data=filel3, x="Response", hue="Income", multiple="stack")
sns.set(rc={"figure.figsize":(8, 4)}) #IDEM
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# ~\anaconda3\lib\site-packages\IPython\core\pylabtools.py in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     149         FigureCanvasBase(fig)
#     150
# --> 151     fig.canvas.print_figure(bytes_io, **kw)
#     152     data = bytes_io.getvalue()
#     153     if fmt == 'svg':
#
# ~\anaconda3\lib\site-packages\matplotlib\backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
# ...

# %%
# Lab | Customer Analysis Round 4
#In today's lesson we talked about continuous distributions (mainly normal distribution), 
#linear regression and how multicollinearity can impact the model.
#In this lab, we will test your knowledge on those things using the marketing_customer_analysis.csv file. 
#You have been using the same data in the previous labs (round 2 and 3). You can continue using the same jupyter file. 
#The file can be found in the files_for_lab folder.
#Please note that we will use the column total_claim_amount later as the target variable.

# %%
#Get the data
#Use the jupyter file from the last lab (Customer Analysis Round 3)
#I downloaded the marketing_customer_analysis file for lab 4,compared it with the file for lab 3 and they are the same.
#No need to download again.

# %%
#Check the data types of the columns. 
#Get the numeric data into dataframe called numerical and categorical columns in a dataframe called categoricals. 
#(You can use np.number and np.object to select the numerical data types and categorical data types respectively)

# %%
filel3.describe(include=[np.object]).T
# Out:
# C:\Users\31612\AppData\Local\Temp/ipykernel_13668/2217130784.py:1: DeprecationWarning: `np.object` is a deprecated alias for the builtin `object`. To silence this warning, use `object` by itself. Doing this will not modify any behavior and is safe.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   filel3.describe(include=[np.object]).T
#                   count unique            top  freq
# Customer           9134   9134        BU79786     1
# State              9134      5     California  3150
# Response           9134      2             No  7826
# Coverage           9134      3          Basic  5568
# Education          9134      5       Bachelor  2748
# Effective To Date  9134     59        1/10/11   195
# EmploymentStatus   9134      5       Employed  5698
# Gender             9134      2              F  4658
# Location Code      9134      3       Suburban  5779
# ...

# %%
categorical = filel3.iloc[:, [0,1,3,4,5,6,7,8,10,11,17,18,19,20,22,23]]
categorical.head()
# Out:
#   Customer       State Response  Coverage Education Effective To Date  \
# 0  BU79786  Washington       No     Basic  Bachelor           2/24/11
# 1  QZ44356     Arizona       No  Extended  Bachelor           1/31/11
# 2  AI49188      Nevada       No   Premium  Bachelor           2/19/11
# 3  WW63253  California       No     Basic  Bachelor           1/20/11
# 4  HB64268  Washington       No     Basic  Bachelor            2/3/11
#
#   EmploymentStatus Gender Location Code Marital Status     Policy Type  \
# 0         Employed      F      Suburban        Married  Corporate Auto
# 1       Unemployed      F      Suburban         Single   Personal Auto
# 2         Employed      F      Suburban        Married   Personal Auto
# 3       Unemployed      M      Suburban        Married  Corporate Auto
# 4         Employed      M         Rural         Single   Personal Auto
#
#          Policy Renew Offer Type Sales Channel  Vehicle Class Vehicle Size
# ...

# %%
numerical = filel3.iloc[:, [2,9,12,13,14,15,16,21]]
numerical.head()
# Out:
#    Customer Lifetime Value  Income  Monthly Premium Auto  \
# 0              2763.519279   56274                    69
# 1              6979.535903       0                    94
# 2             12887.431650   48767                   108
# 3              7645.861827       0                   106
# 4              2813.692575   43836                    73
#
#    Months Since Last Claim  Months Since Policy Inception  \
# 0                       32                              5
# 1                       13                             42
# 2                       18                             38
# 3                       18                             65
# 4                       12                             44
#
#    Number of Open Complaints  Number of Policies  Total Claim Amount
# 0                          0                   1          384.811147
# 1                          0                   8         1131.464935
# ...

# %%
#Now we will try to check the normality of the numerical variables visually
#Use seaborn library to construct distribution plots for the numerical variables
#Use Matplotlib to construct histograms

# %%
sns.distplot(numerical['Total Claim Amount'], bins=40)
# Out:
# C:\Users\31612\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Total Claim Amount', ylabel='Density'>

# %%
sns.distplot(numerical['Total Claim Amount'], bins=40)
# Out:
# C:\Users\31612\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Total Claim Amount', ylabel='Density'>

# %%
numerical[['Total Claim Amount']].hist(bins=15)
plt.show()

# %%
sns.distplot(numerical['Number of Policies'], bins=40)
# Out:
# C:\Users\31612\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Number of Policies', ylabel='Density'>

# %%
numerical[['Number of Policies']].hist(bins=30)
plt.show()

# %%
sns.distplot(numerical['Number of Open Complaints'], bins=40)
# Out:
# C:\Users\31612\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Number of Open Complaints', ylabel='Density'>

# %%
numerical[['Number of Open Complaints']].hist(bins=6)
plt.show()

# %%
sns.distplot(numerical['Months Since Policy Inception'], bins=30)
# Out:
# C:\Users\31612\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Months Since Policy Inception', ylabel='Density'>

# %%
numerical[['Months Since Policy Inception']].hist(bins=30)
plt.show()

# %%
sns.distplot(numerical['Months Since Last Claim'], bins=30)
# Out:
# C:\Users\31612\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Months Since Last Claim', ylabel='Density'>

# %%
numerical[['Months Since Last Claim']].hist(bins=30)
plt.show()

# %%
sns.distplot(numerical['Monthly Premium Auto'], bins=30)
# Out:
# C:\Users\31612\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Monthly Premium Auto', ylabel='Density'>

# %%
numerical[['Monthly Premium Auto']].hist(bins=6)
plt.show()

# %%
sns.distplot(numerical['Income'], bins=6)
# Out:
# C:\Users\31612\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Income', ylabel='Density'>

# %%
numerical[['Income']].hist(bins=6)
plt.show()

# %%
sns.distplot(numerical['Customer Lifetime Value'], bins=30)
# Out:
# C:\Users\31612\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Customer Lifetime Value', ylabel='Density'>

# %%
numerical[['Customer Lifetime Value']].hist(bins=30)
plt.show()

# %%
#Do the distributions for different numerical variables look like a normal distribution
#For the numerical variables, check the multicollinearity between the features.

# %%
#normalize values in every column
num_norm = (numerical-numerical.min())/ (numerical.max() - numerical.min())
#view normalized DataFrame
num_norm
# Out:
#       Customer Lifetime Value    Income  Monthly Premium Auto  \
# 0                    0.010629  0.562847              0.033755
# 1                    0.062406  0.000000              0.139241
# 2                    0.134960  0.487763              0.198312
# 3                    0.070589  0.000000              0.189873
# 4                    0.011245  0.438443              0.050633
# ...                       ...       ...                   ...
# 9129                 0.264137  0.719547              0.050633
# 9130                 0.014719  0.216081              0.075949
# 9131                 0.076951  0.000000              0.101266
# 9132                 0.069098  0.219452              0.147679
# 9133                 0.008766  0.000000              0.067511
#
#       Months Since Last Claim  Months Since Policy Inception  \
# 0                    0.914286                       0.050505
# 1                    0.371429                       0.424242
# ...

# %%
#Write code for both the correlation matrix and for seaborn heatmap. 
#If there is no pair of features that have a high correlation, then do not drop any features
#For the numerical variables, check the multicollinearity between the features.
#Please note that we will use the column total_claim_amount later as the target variable.
#Drop one of the two features that show a high correlation between them (greater than 0.9). 
#Write code for both the correlation matrix and for seaborn heatmap. 
#If there is no pair of features that have a high correlation, then do not drop any features

# %%
sns.pairplot(num_norm)
plt.show()

# %%
numcorr = num_norm.corr()
numcorr
# Out:
#                                Customer Lifetime Value    Income  \
# Customer Lifetime Value                       1.000000  0.024366
# Income                                        0.024366  1.000000
# Monthly Premium Auto                          0.396262 -0.016665
# Months Since Last Claim                       0.011517 -0.026715
# Months Since Policy Inception                 0.009418 -0.000875
# Number of Open Complaints                    -0.036343  0.006408
# Number of Policies                            0.021955 -0.008656
# Total Claim Amount                            0.226451 -0.355254
#
#                                Monthly Premium Auto  Months Since Last Claim  \
# Customer Lifetime Value                    0.396262                 0.011517
# Income                                    -0.016665                -0.026715
# Monthly Premium Auto                       1.000000                 0.005026
# ...

# %%
fig, ax = plt.subplots(figsize=(10, 8))
ax = sns.heatmap(numcorr, annot=True)
plt.show()

# %%
#There are no features that show a correlation between them higher than 0.9. 
#We will not drop any feature.
#The two parameters that seem to have the highest explanation capacity for total claim amount are income, monthly premium auto and customer lifetime value.
#Customer Lifetime value has a 0.4 correlation with monthly premium auto.
#We will have to see if it has new explanation capacity.

# %%
#Customer analysis round 5
#For this lab, we still keep using the marketing_customer_analysis.csv file that you can find in the files_for_lab folder.
#ALREADY DONE
#Get the data
#We are using the marketing_customer_analysis.csv file.

#Dealing with the data#Already done in the round 2.#Explore the data#Done in the round 3.#Processing Data
#(Further processing...)
#Normalize (numerical).

# %%
#X-y split.

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
lm = LinearRegression()

# %%
X = numerical.iloc[:, :-1]  #taking the dataset that is not normalised. X is the matrix of independent variables.
y = numerical.iloc[:, -1]   #y is the vector of the dependent variable. 
#This piece of code can also be used, it is more efficient as it does not depend on the position in the dataset.
#Y = data['Total Value Claim']
#X = data.drop(['Total Value Claim'], axis=1)
display(X)
display(y)
# Out:
#       Customer Lifetime Value  Income  Monthly Premium Auto  \
# 0                 2763.519279   56274                    69
# 1                 6979.535903       0                    94
# 2                12887.431650   48767                   108
# 3                 7645.861827       0                   106
# 4                 2813.692575   43836                    73
# ...                       ...     ...                   ...
# 9129             23405.987980   71941                    73
# 9130              3096.511217   21604                    79
# 9131              8163.890428       0                    85
# 9132              7524.442436   21941                    96
# 9133              2611.836866       0                    77
#
#       Months Since Last Claim  Months Since Policy Inception  \
# 0                          32                              5
# 1                          13                             42
# ...

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y,test_size = 0.2, random_state = 1)

# %%
display(X_train)
# Out:
#       Customer Lifetime Value  Income  Monthly Premium Auto  \
# 8130              4118.588554   69379                   103
# 6946              5517.199137   60596                    71
# 7993              7842.865664   94263                    98
# 3554              4196.652176       0                    64
# 3296              5258.251562   37874                    65
# ...                       ...     ...                   ...
# 2895             19435.629240   38688                   249
# 7813              5686.743252   26409                    71
# 905              10952.131890   23748                    99
# 5192             10377.368420       0                    95
# 235               5912.783829   72208                    73
#
#       Months Since Last Claim  Months Since Policy Inception  \
# 8130                       14                             79
# 6946                       20                             78
# ...

# %%
display(X_test)
# Out:
#       Customer Lifetime Value  Income  Monthly Premium Auto  \
# 2740              5623.757656   77912                    71
# 6984              6051.637445       0                    88
# 623               2606.208503   28519                    66
# 307              10272.608200   60145                   132
# 7956             11828.614370       0                   111
# ...                       ...     ...                   ...
# 6971             14040.964760       0                   195
# 8448              2839.945741   53444                    72
# 8441              5953.352957   20283                    77
# 8108             24108.300570   17257                    70
# 2564              8509.019846   56481                   106
#
#       Months Since Last Claim  Months Since Policy Inception  \
# 2740                        2                             21
# 6984                       16                             80
# ...

# %%
display(y_train)
# Out:
# 8130     494.400000
# 6946     180.340069
# 7993     112.420211
# 3554     774.737185
# 3296      41.016038
#            ...
# 2895    2294.631639
# 7813     475.166267
# 905      607.095655
# 5192     579.452318
# 235      350.400000
# Name: Total Claim Amount, Length: 7307, dtype: float64

# %%
display(y_test)
# Out:
# 2740      23.898160
# 6984     633.600000
# 623      456.473115
# 307      580.473259
# 7956    1018.808223
#            ...
# 6971     669.037562
# 8448     315.703929
# 8441     369.600000
# 8108     551.132139
# 2564     273.250112
# Name: Total Claim Amount, Length: 1827, dtype: float64

# %%
#training the model
numericallm = LinearRegression() #creating the simple regression model , we have to connect it with the dataset. 
model = numericallm.fit(X_train,y_train)
y_pred_train = numericallm.predict(X_train)
r2_score_train = r2_score(y_pred_train, y_train)
display(r2_score_train)
# Out:
# 0.07925201603611098

# %%
y_pred_test = numericallm.predict(X_test)
display(y_test)
# Out:
# 2740      23.898160
# 6984     633.600000
# 623      456.473115
# 307      580.473259
# 7956    1018.808223
#            ...
# 6971     669.037562
# 8448     315.703929
# 8441     369.600000
# 8108     551.132139
# 2564     273.250112
# Name: Total Claim Amount, Length: 1827, dtype: float64

# %%
r2_score_test = r2_score(y_pred_test, y_test)
r2_score_test
# Out:
# 0.15799030725146002

# %%
sns.scatterplot(x='Monthly Premium Auto',y='Total Claim Amount',data=numerical)
plt.show()

# %%
sns.scatterplot(x='Income',y='Total Claim Amount',data=numerical)
plt.show()

# %%
sns.scatterplot(x='Customer Lifetime Value',y='Total Claim Amount',data=numerical)
plt.show()

# %%
#Customer analysis round 6

One Hot/Label Encoding (categorical).
Concat DataFrames
Linear Regression
Train-test split.
Apply linear regression.
Model Validation
Description:
R2.
MSE.
RMSE.
MAE.

# %%
#Customer analysis round 6

One Hot/Label Encoding (categorical).
Concat DataFrames
Linear Regression
Train-test split.
Apply linear regression.
Model Validation
Description:
R2.
MSE.
RMSE.
MAE.

# %%
#Customer analysis round 7
#Remember the previous rounds. Follow the steps as shown in previous lectures and try to improve the accuracy of the model. Include both categorical columns in the exercise. Some approaches you can try in this exercise:

#use the concept of multicollinearity and remove insignificant variables
#use a different method of scaling the numerical variables
#use a different ratio of train test split
#use the transformation on numerical columns which align it more towards a normal distribution
#Get the data
#We are using the marketing_customer_analysis.csv file.

Dealing with the data
Already done in rounds 2 to 7.

#Bonus: Build a function, from round 2 and round 7, to clean and process the data.

Explore the data
Done in the round 3.

Modeling
Description:

#Try to improve the linear regression model.
